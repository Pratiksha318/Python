# %%
import pandas as pd

# %%
pd.__version__
# Out:
# '1.1.3'

# %%
# Create Dataframe
df=pd.DataFrame([11,22,33],columns=['Col_name'])
print(df)
# Out:
#    Col_name
# 0        11
# 1        22
# 2        33

# %%
print(type(df))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
Data={
    'Name':['Mathav','Vishaka','Lalita','Rishabh'],
    'Age':[12,13,14,15],
    'Salary':[20000,30000,40000,50000]
}

# %%
df=pd.DataFrame(Data)

# %%
df
# Out:
#       Name  Age  Salary
# 0   Mathav   12   20000
# 1  Vishaka   13   30000
# 2   Lalita   14   40000
# 3  Rishabh   15   50000

# %%
# Basic Dataframe Understanding
df.head()
# Out:
#       Name  Age  Salary
# 0   Mathav   12   20000
# 1  Vishaka   13   30000
# 2   Lalita   14   40000
# 3  Rishabh   15   50000

# %%
df.head(2)
# Out:
#       Name  Age  Salary
# 0   Mathav   12   20000
# 1  Vishaka   13   30000

# %%
df.tail()
# Out:
#       Name  Age  Salary
# 0   Mathav   12   20000
# 1  Vishaka   13   30000
# 2   Lalita   14   40000
# 3  Rishabh   15   50000

# %%
df.shape
# Out:
# (4, 3)

# %%
df.columns
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='object')

# %%
df.rename(columns={'Salary':'Monthly_Salary'},inplace=True)

# %%
df
# Out:
#       Name  Age  Monthly_Salary
# 0   Mathav   12           20000
# 1  Vishaka   13           30000
# 2   Lalita   14           40000
# 3  Rishabh   15           50000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      object
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), object(1)
# memory usage: 224.0+ bytes

# %%
df.describe()
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   13.500000    35000.000000
# std     1.290994    12909.944487
# min    12.000000    20000.000000
# 25%    12.750000    27500.000000
# 50%    13.500000    35000.000000
# 75%    14.250000    42500.000000
# max    15.000000    50000.000000

# %%
# Save and Load Dataframe from csv

# %%
df.to_csv('Test_data.csv',index=False)# dataframne.to_csv,,,,,export dataframe

# %%
load_df=pd.read_csv('Test_data.csv')#import dataframe
load_df
# Out:
#       Name  Age  Monthly_Salary
# 0   Mathav   12           20000
# 1  Vishaka   13           30000
# 2   Lalita   14           40000
# 3  Rishabh   15           50000

# %%
# Rows and Column Selection

# %%
#df[['Name']] #single column
df[['Name','Monthly_Salary']]  #
# Out:
#       Name  Monthly_Salary
# 0   Mathav           20000
# 1  Vishaka           30000
# 2   Lalita           40000
# 3  Rishabh           50000

# %%
#Select Rows
df.loc[df.Name=='Lalita']
# Out:
#      Name  Age  Monthly_Salary
# 2  Lalita   14           40000

# %%
df.loc[(df.Name=='Vishaka')&(df.Monthly_Salary>30000)]
# Out:
# Empty DataFrame
# Columns: [Name, Age, Monthly_Salary]
# Index: []

# %%
df.iloc[0] #index value based
# Out:
# Name              Mathav
# Age                   12
# Monthly_Salary     20000
# Name: 0, dtype: object

# %%
df.iloc[0:2]
# Out:
#       Name  Age  Monthly_Salary
# 0   Mathav   12           20000
# 1  Vishaka   13           30000

# %%
df
# Out:
#       Name  Age  Monthly_Salary
# 0   Mathav   12           20000
# 1  Vishaka   13           30000
# 2   Lalita   14           40000
# 3  Rishabh   15           50000

# %%
df['Age']>12
# Out:
# 0    False
# 1     True
# 2     True
# 3     True
# Name: Age, dtype: bool

# %%
 df_age_filter=df[df['Age']>12]
df_age_filter
# Out:
#       Name  Age  Monthly_Salary
# 1  Vishaka   13           30000
# 2   Lalita   14           40000
# 3  Rishabh   15           50000

# %%
df[(df['Age']>=12) & (df['Monthly_Salary']>=20000)]
# Out:
#       Name  Age  Monthly_Salary
# 0   Mathav   12           20000
# 1  Vishaka   13           30000
# 2   Lalita   14           40000
# 3  Rishabh   15           50000

# %%
df.where(df['Age']>=13)
# Out:
#       Name   Age  Monthly_Salary
# 0      NaN   NaN             NaN
# 1  Vishaka  13.0         30000.0
# 2   Lalita  14.0         40000.0
# 3  Rishabh  15.0         50000.0

# %%
df.where(df['Age']>=14, other='Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2        Lalita            14          40000
# 3       Rishabh            15          50000

# %%
# Rows and Column -Operation

# %%
#Add new column
df['Team']=['CEO','HR','CTO','DA']
df
# Out:
#       Name  Age  Monthly_Salary Team
# 0   Mathav   12           20000  CEO
# 1  Vishaka   13           30000   HR
# 2   Lalita   14           40000  CTO
# 3  Rishabh   15           50000   DA

# %%
df['Bonus']=df['Monthly_Salary']*0.2
df
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Mathav   12           20000  CEO   4000.0
# 1  Vishaka   13           30000   HR   6000.0
# 2   Lalita   14           40000  CTO   8000.0
# 3  Rishabh   15           50000   DA  10000.0

# %%
#Add new row
df.loc[len(df)]=['ABC',15,25000,'IT',2000]
df
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Mathav   12           20000  CEO   4000.0
# 1  Vishaka   13           30000   HR   6000.0
# 2   Lalita   14           40000  CTO   8000.0
# 3  Rishabh   15           50000   DA  10000.0
# 4      ABC   15           25000   IT   2000.0

# %%
len(df)
# Out:
# 5

# %%
#Update value-using index name
df.loc[0,'Monthly_Salary']=25000
df
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Mathav   12           25000  CEO   4000.0
# 1  Vishaka   13           30000   HR   6000.0
# 2   Lalita   14           40000  CTO   8000.0
# 3  Rishabh   15           50000   DA  10000.0
# 4      ABC   15           25000   IT   2000.0

# %%
#Update value-using column name
df.loc[df.Name=='Lalita','Monthly_Salary']=45000
df
# Out:
#       Name  Age  Monthly_Salary Team    Bonus  Salary
# 0   Mathav   12           25000  CEO   4000.0     NaN
# 1  Vishaka   13           30000   HR   6000.0     NaN
# 2   Lalita   14           45000  CTO   8000.0     NaN
# 3  Rishabh   15           50000   DA  10000.0     NaN
# 4      ABC   15           25000   IT   2000.0     NaN

# %%
df.loc[df.Name=='Mathav','Monthly_Salary']=45000
df
# Out:
#       Name  Age  Monthly_Salary Team    Bonus  Salary
# 0   Mathav   12           45000  CEO   4000.0     NaN
# 1  Vishaka   13           30000   HR   6000.0     NaN
# 2   Lalita   14           45000  CTO   8000.0     NaN
# 3  Rishabh   15           50000   DA  10000.0     NaN
# 4      ABC   15           25000   IT   2000.0     NaN

# %%
#Delete value--row and column
df.drop(df[df.Name=='ABC'].index)  # drop row, axis 0
# Out:
#       Name  Age  Monthly_Salary Team    Bonus  Salary
# 0   Mathav   12           45000  CEO   4000.0     NaN
# 1  Vishaka   13           30000   HR   6000.0     NaN
# 2   Lalita   14           45000  CTO   8000.0     NaN
# 3  Rishabh   15           50000   DA  10000.0     NaN

# %%
[df.Name=='ABC']
# Out:
# [0    False
#  1    False
#  2    False
#  3    False
#  4     True
#  Name: Name, dtype: bool]

# %%
df[df.Name=='ABC']
# Out:
#   Name  Age  Monthly_Salary Team   Bonus  Salary
# 4  ABC   15           25000   IT  2000.0     NaN

# %%
df.drop('Salary',axis=1,inplace=True) # drop column axis=1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-70-2606a68a333a> in <module>
# ----> 1 df.drop('Salary',axis=1,inplace=True) # drop column axis=1
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4161                 weight  1.0     0.8
#    4162         """
# -> 4163         return super().drop(
#    4164             labels=labels,
#    4165             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3885         for axis, labels in axes.items():
#    3886             if labels is not None:
# -> 3887                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    3888
#    3889         if inplace:
#
# ...

# %%
df.drop(['Bonus','Team'],axis=1)
# Out:
#       Name  Age  Monthly_Salary
# 0   Mathav   12           45000
# 1  Vishaka   13           30000
# 2   Lalita   14           45000
# 3  Rishabh   15           50000
# 4      ABC   15           25000

# %%
df.drop(1,axis=0) # using index va;ue
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Mathav   12           45000  CEO   4000.0
# 2   Lalita   14           45000  CTO   8000.0
# 3  Rishabh   15           50000   DA  10000.0
# 4      ABC   15           25000   IT   2000.0

# %%
df
# Out:
#       Name  Age  Monthly_Salary Team    Bonus
# 0   Mathav   12           45000  CEO   4000.0
# 1  Vishaka   13           30000   HR   6000.0
# 2   Lalita   14           45000  CTO   8000.0
# 3  Rishabh   15           50000   DA  10000.0
# 4      ABC   15           25000   IT   2000.0

# %%
df.rename(columns={'Monthly_Salary':'salary'},inplace=True)
df
# Out:
#       Name  Age  salary Team    Bonus
# 0   Mathav   12   45000  CEO   4000.0
# 1  Vishaka   13   30000   HR   6000.0
# 2   Lalita   14   45000  CTO   8000.0
# 3  Rishabh   15   50000   DA  10000.0
# 4      ABC   15   25000   IT   2000.0

# %%
df.sort_values('Age')
# Out:
#       Name  Age  salary Team    Bonus
# 0   Mathav   12   45000  CEO   4000.0
# 1  Vishaka   13   30000   HR   6000.0
# 2   Lalita   14   45000  CTO   8000.0
# 3  Rishabh   15   50000   DA  10000.0
# 4      ABC   15   25000   IT   2000.0

# %%
df.sort_values('salary',ascending=False) # desending order
# Out:
#       Name  Age  salary Team    Bonus
# 3  Rishabh   15   50000   DA  10000.0
# 0   Mathav   12   45000  CEO   4000.0
# 2   Lalita   14   45000  CTO   8000.0
# 1  Vishaka   13   30000   HR   6000.0
# 4      ABC   15   25000   IT   2000.0

# %%
# working with data values

# %%
# Handing Missing Value
df
# Out:
#       Name  Age  salary Team    Bonus
# 0   Mathav   12   45000  CEO   4000.0
# 1  Vishaka   13   30000   HR   6000.0
# 2   Lalita   14   45000  CTO   8000.0
# 3  Rishabh   15   50000   DA  10000.0
# 4      ABC   15   25000   IT   2000.0

# %%
df.isnull()
# Out:
#     Name    Age  salary   Team  Bonus
# 0  False  False   False  False  False
# 1  False  False   False  False  False
# 2  False  False   False  False  False
# 3  False  False   False  False  False
# 4  False  False   False  False  False

# %%
import numpy as np

# %%
df.loc[df.Name=='Rishabh','salary']=np.nan

# %%
df
# Out:
#       Name  Age   salary Team    Bonus
# 0   Mathav   12  45000.0  CEO   4000.0
# 1  Vishaka   13  30000.0   HR   6000.0
# 2   Lalita   14  45000.0  CTO   8000.0
# 3  Rishabh   15      NaN   DA  10000.0
# 4      ABC   15  25000.0   IT   2000.0

# %%
df.isnull()
# Out:
#     Name    Age  salary   Team  Bonus
# 0  False  False   False  False  False
# 1  False  False   False  False  False
# 2  False  False   False  False  False
# 3  False  False    True  False  False
# 4  False  False   False  False  False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# salary    1
# Team      0
# Bonus     0
# dtype: int64

# %%
df.fillna(0)
# Out:
#       Name  Age   salary Team    Bonus
# 0   Mathav   12  45000.0  CEO   4000.0
# 1  Vishaka   13  30000.0   HR   6000.0
# 2   Lalita   14  45000.0  CTO   8000.0
# 3  Rishabh   15      0.0   DA  10000.0
# 4      ABC   15  25000.0   IT   2000.0
